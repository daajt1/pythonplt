# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x,100)
plt.title("normal distribution with $\mu=0, \sigma = 1$")
plt.savefig("matplotlib_histogram.png")
plt.show()

# %%
plt.plot(1,5,"o")
plt.show()

# %%
import numpy as np
import pandas as pd
# !pip install xlrd
df = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx', 
                   sheet_name = 'Canada by Citizenship', skiprows = range(20),skipfooter = 2)
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.6/dist-packages (1.1.0)

# %%
df.columns = df.columns.astype(str)
df.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df = df.rename(columns = {"OdName":"Country"})

# %%
df.set_index("Country", inplace = True)

# %%
df['Total'] = df.iloc[:,9:43].sum(axis = 1)

# %%
df.head()
# Out:
#                       Type    Coverage  AREA AreaName  ...  2011  2012  2013  Total
# Country                                                ...
# Afghanistan     Immigrants  Foreigners   935     Asia  ...  2203  2635  2004  58623
# Albania         Immigrants  Foreigners   908   Europe  ...   539   620   603  15698
# Algeria         Immigrants  Foreigners   903   Africa  ...  4325  3774  4331  69359
# American Samoa  Immigrants  Foreigners   909  Oceania  ...     0     0     0      6
# Andorra         Immigrants  Foreigners   908   Europe  ...     0     1     1     15
#
# [5 rows x 43 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline


years = list(map(str, range(1980,2014)))

df.loc['Haiti', years].plot(kind = 'line')
plt.title('Immigration from Haiti')
plt.ylabel("Number of Immigrants")
plt.xlabel("Years")

plt.show()
